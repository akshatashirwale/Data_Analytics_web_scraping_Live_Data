# %% [markdown]
# <h1><center>Data Analysis Web Scraping</center></h1>

# %% [markdown]
# ### Introduction to Web Scraping
#
# Consider the following scenario: you need to pull an enormous volume of data from websites as rapidly as workable. How would you do it if you didn’t go to each website and manually collect the data? Well, the answer is “web scraping”. Scraping the web makes this process a lot easier and faster.
#
# ![1.svg](attachment:1.svg)
#
# ### What is Web Scraping?
#
# Web scraping is a computer software technique of extracting information from websites. This technique mostly focuses on the transformation of unstructured data (HTML format) on the web into structured data (database or spreadsheet).
#
# We can perform web scraping in various ways, including use of Google Docs to almost every programming language.

# %% [markdown]
# ### Now the question is how do we get data from websites?
#
# When any web scraping code is run the request is sent to the URL that you have mentioned. The website responds to the request by sending data and allows it to read the XML or HTML page. The code will then extract the required data from that XML or HTML page.
#
# Any web scraping code you need to follow the basic steps:
#
# 1. Find the URL(address) of web page you want to scrape
# 2. Inspect the page and find the data you want to extract
# 3. Write the logic for extracting the data
# 4. Store extracted data into structured form(E.g. Pandas DataFrame)
#
# Now we’ll perform web scraping with various libraries and framework.

# %% [markdown]
# ### Step-by-Step process to Scrape Data From A Website:
#
# Web scraping is gaining data from web pages using HTML parsing. Something data is available in CSV or JSON format from some websites, but this is not always the case, causing the use of web scraping.
#
# When you run the web scraping code, it sends a request to the URL you specified. The server provides the data in response to your request, allowing you to see the HTML or XML page. The code then parses the HTML or XML page, locating and extracting the data.

# %% [markdown]
# ### Why is python used for web scraping?
#
# 1) Python includes many libraries, such as Numpy, Matplotlib, Pandas, and others, that provide methods and functions for a variety of uses. As a result, it’s suitable for web crawling and additional data manipulation.
#
# 2) Python is an easy language to program in. There are no semi-colons “;” or curly-braces “{}” required anywhere. So it is easier to use and less noisy.
#
# 3) Dynamically typed: You don’t have to define data types for variables in Python; you can just use them wherever they’re needed. This saves you time and speeds up your work.
#
# 4) Small code, long process: Web scraping is a technique for saving time. But what good is it if you waste more time writing code? You don’t have to, though. We can write small codes in Python to accomplish large tasks. As a result, even while writing the code, you save time.
#
# 5) Python syntax is simple to learn because reading Python code is quite understandable compared to reading a statement in English. Python’s indentation helps the user distinguish between distinct scopes/blocks in the code, making it expressive and easy to understand.

# %% [markdown]
# ### Libraries used for Web Scraping in Python
#
# You’ll come across multiple libraries and frameworks in Python for web scraping.
#
# **Here are three popular Libraries**
#
# ##### BeautifulSoup
#
# - BeautifulSoup is an amazing parsing library in Python that enables the web scraping from HTML and XML documents.
#
# - BeautifulSoup automatically detects encodings and gracefully handles HTML documents even with special characters. We can navigate a parsed document and find what we need which makes it quick and painless to extract the data from the webpages.
#
# ##### Scrapy
#
# - Scrapy is a Python framework for large scale web scraping. It gives you all the tools you need to efficiently extract data from websites, process them as you want, and store them in your preferred structure and format.
#
# ##### Selenium
#
# - Selenium is another popular tool for automating browsers. It’s primarily used for testing in the industry but is also very handy for web scraping.

# %% [markdown]
# # Implementation using BeautifulSoup

# %% [markdown]
# **Install BeautifulSoup:** pip install beautifulsoup4

# %%
import requests  # Importing the requests library for making HTTP requests
import pandas as pd  # Importing the pandas library for data manipulation
from bs4 import BeautifulSoup  # Importing BeautifulSoup for web scraping

# %% [markdown]
# - Get URL from Flipkart based upon your product

# %%
url = "https://www.flipkart.com/search?q=mi%20brand%20phone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
url
# Out:
# 'https://www.flipkart.com/search?q=mi%20brand%20phone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
# sends an HTTP GET request to the specified URL and assigns the response object to the variable req
req = requests.get(url)

# %%
# parses the HTML content of the response obtained from the req object using BeautifulSoup library and assigns it to the variable content
content = BeautifulSoup(req.content, 'html.parser')
content
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/><meta content="app" name="twitter:card"/><meta content="@flipkart" name="twitter:site"/><meta content="@flipkart" name="twitter:creator"/><meta content="Mi Brand Phone- Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="twitter:title"/><meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/><meta content="in" name="twitter:app:country"/><meta content="Flipkart" name="al:ios:app_name"/><meta content="742044692" name="al:ios:app_store_id"/><meta content="Flipkart" name="twitter:app:name:iphone"/><meta content="742044692" name="twitter:app:id:iphone"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/><meta content="Flipkart" name="twitter:app:name:ipad"/><meta content="742044692" name="twitter:app:id:ipad"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/><meta content="Flipkart" name="twitter:app:name:googleplay"/><meta content="com.flipkart.android" name="twitter:app:id:googleplay"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/><style>#container {
# 			height: 100%;
# 		}</style> <link href="///fk-cp-zion/css/Browse.chunk.b2aeab.css" rel="stylesheet"/><title>Mi Brand Phone- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title><meta content="Mi Brand Phone- Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="og_title" property="og:title"><meta content="Mi Brand Phone" name="Keywords"> <meta content="Mi Brand Phone- Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" name="Description"><meta content="Mi Brand Phone- Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" property="og:description"> <meta content="noindex" name="robots"> <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01"> <!--[if IE 9 ]>
# 	<script nonce="16846393364431464201">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]--><!--[if !IE]><!--><script nonce="16846393364431464201">if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}</script><!--<![endif]--> <link href="https://www.flipkart.com/search?q=mi+brand+phone&amp;otracker=search&amp;otracker1=search&amp;marketplace=FLIPKART&amp;as-show=on&amp;as=off&amp;page=2" id="next-page-link-tag" rel="next"/><script nonce="16846393364431464201">!function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#
# 		if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#
#         // web-vitals polyfill for FID
#         !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-594691041"></script><script nonce="16846393364431464201">window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments)};
# 		gtag('js', new Date());</script></meta></meta></meta></meta></meta></meta></head><body><div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="mi brand phone"/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#2874F1" fill-rule="evenodd"><path class="_34RNph" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203"></path><path class="_34RNph" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467"></path></g></svg></button><input name="otracker" type="hidden" value="search"/><input name="otracker1" type="hidden" value="search"/><input name="marketplace" type="hidden" value="FLIPKART"/><input name="as-show" type="hidden" value="off"/><input name="as" type="hidden" value="off"/></div><ul class="col-12-12 _1MRYA1"></ul></form></div><div class="go_DOp _2errNR"><div class="_28p97w"><div class="_1psGvi _3BvnxG"><div><a class="_1_3w1N" href="/account/login?ret=/search%3Fq%3Dmi%2520brand%2520phone%26otracker%3Dsearch%26otracker1%3Dsearch%26marketplace%3DFLIPKART%26as-show%3Don%26as%3Doff">Login</a></div></div></div></div><div class="go_DOp"><a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a></div><div class="go_DOp"><div class="_28p97w"><div class="_1psGvi _3BvnxG"><div><div class="exehdJ"> <!-- -->More<!-- --> </div></div></div><svg class="zZ3yfL" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_2gTTdy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div></div><div class="go_DOp"><div class="_1psGvi"><div class="YUhWwv"><a class="_3SkBxJ" href="/viewcart?exploreMode=true&amp;preference=FLIPKART"><svg class="V3C5bO" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg"><path class="_1bS9ic" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff"></path></svg><span>Cart</span></a></div></div></div></div><div class="_1TmfNK"></div></div><div class="_1mUdNz"></div></div><div class="_331-kn"></div><div class="_36fx1h _6t1WkM _3HqJxg"><div class="_1YokD2 _2GoDe3"><div class="_1YokD2 _3Mn1Gg col-2-12" style="flex:0 0 280px;max-width:280px;padding:0px 10px 0px 0px"><div class="_1YokD2 _3Mn1Gg col-12-12"><div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div cl ...
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India</p>
# </div></div></div><div class="_3-dnWo">Social</div><div class="_2SkNJs"><span class="_2iAEVP"><a href="https://www.facebook.com/flipkart"><img height="24" src="data:image/svg+xml;base64,..." width="24"/></a></span><span class="_2iAEVP"><a href="https://www.twitter.com/flipkart"><img height="24" src="data:image/svg+xml;base64,..." width="24"/></a></span><span class="_2iAEVP"><a href="https://www.youtube.com/flipkart"><img height="24" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/YoutubeLogo_958b78.svg" width="24"/></a></span></div></div></div><div class="_2Brcj4 address"><div class="_3IT4e6"><div class="_3-dnWo"><span>Registered Office Address:</span></div><div class="_1U1qnR"><div class="_1LJS6T"><div class="_2NKhZn _1U1qnR"><p>Flipkart Internet Private Limited, </p>
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India </p>
# <p> CIN : U51109KA2012PTC066107 </p>
# <p> Telephone: <a href="tel:044-45614700">044-45614700</a></p>
# </div></div></div></div></div></div><div><div class="_2uz0vJ"><div><img src="data:image/svg+xml;base64,..."/><a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span class="hDTmm5">Become a Seller</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="https://brands.flipkart.com"><span class="hDTmm5">Advertise</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/the-gift-card-store?otracker=undefined_footer_footer_navlinks"><span class="hDTmm5">Gift Cards</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/helpcentre?otracker=undefined_footer_footer_navlinks"><span class="hDTmm5">Help Center</span></a></div><span class="z3ht-w">© 2007-<!-- -->2024<!-- --> <span>Flipkart.com</span></span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/payment-method_69e7ec.svg"/></div></div></div></div></footer><div class="_1EcK2J _38JCdA"><div class="bra6U8"><svg class="_2TdLiZ" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_3ZKfA2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg><span>Back to top</span></div></div></div></div> <script id="jsonLD" nonce="16846393364431464201" type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.flipkart.com/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&lid=LSTMOBG3VSKHGETEBVM0TO8SZ&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Mi 11 Lite (Vinyl Black, 128 GB)"},{"@type":"ListItem","position":2,"url":"https://www.flipkart.com/mi-11-lite-jazz-blue-128-gb/p/itme2c379bf49448?pid=MOBG3VSKEVZ3JQVM&lid=LSTMOBG3VSKEVZ3JQVM1QRQHB&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Mi 11 Lite (Jazz Blue, 128 GB)"},{"@type":"ListItem","position":3,"url":"https://www.flipkart.com/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKRKGZKJAR&lid=LSTMOBG3VSKRKGZKJAR9UUSWD&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Mi 11 Lite (Vinyl Black, 128 GB)"},{"@type":"ListItem","position":4,"url":"https://www.flipkart.com/xiaomi-11i-5g-purple-mist-128-gb/p/itmb0fd5926fb0d5?pid=MOBG9QXPXZTUYDY8&lid=LSTMOBG9QXPXZTUYDY81BBAEL&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Xiaomi 11i 5G (Purple Mist, 128 GB)"},{"@type":"ListItem","position":5,"url":"https://www.flipkart.com/mi-10t-pro-cosmic-black-128-gb/p/itm5ff5455fec520?pid=MOBFWAFZASEEEES6&lid=LSTMOBFWAFZASEEEES6ZPPMMT&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Mi 10T Pro (Cosmic Black, 128 GB)"},{"@type":"ListItem","position":6,"url":"https://www.flipkart.com/xiaomi-11i-5g-stealth-black-128-gb/p/itmf5300d828d19f?pid=MOBG9QXPQ2F8KGQD&lid=LSTMOBG9QXPQ2F8KGQDBEHA2F&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Xiaomi 11i 5G (Stealth Black, 128 GB)"},{"@type":"ListItem","position":7,"url":"https://www.flipkart.com/mi-11x-lunar-white-128-gb/p/itmabc334b32f605?pid=MOBG36HSY24GH7GD&lid=LSTMOBG36HSY24GH7GDKM83PH&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Mi 11X (Lunar White, 128 GB)"},{"@type":"ListItem","position":8,"url":"https://www.flipkart.com/redmi-6a-black-16-gb/p/itmdf93c982df80f?pid=MOBF9H95RFHUNBQZ&lid=LSTMOBF9H95RFHUNBQZID6OKJ&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Redmi 6A (Black, 16 GB)"},{"@type":"ListItem","position":9,"url":"https://www.flipkart.com/xiaomi-11i-5g-camo-green-128-gb/p/itm5e173fdb5d441?pid=MOBG9QXPP5QRZZ3P&lid=LSTMOBG9QXPP5QRZZ3PRQPSHC&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Xiaomi 11i 5G (Camo Green, 128 GB)"},{"@type":"ListItem","position":10,"url":"https://www.flipkart.com/redmi-9a-sea-blue-32-gb/p/itmeabd39a0cd669?pid=MOBFVDAYEWNQNKHH&lid=LSTMOBFVDAYEWNQNKHH71ZACK&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io","name":"Redmi 9A (Sea Blue, 32 GB)"}]} ...
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }</script><script id="is_script" nonce="16846393364431464201">window.__INITIAL_STATE__ = {};</script> <link data-chunk="NavMenu" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/NavMenu.chunk.0a28b6.css" rel="stylesheet"/>
# <link data-chunk="SearchFeedback" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/SearchFeedback.chunk.51a13b.css" rel="stylesheet"/> <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[130,205]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["NavMenu","SearchFeedback"]}</script>
# <script async="" data-chunk="NavMenu" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/NavMenu.chunk.c13ed114.js"></script>
# <script async="" data-chunk="SearchFeedback" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/SearchFeedback.chunk.fe89a747.js"></script><script nonce="16846393364431464201">window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;</script><script nonce="16846393364431464201">function isMobile(){
# 		if (!!(navigator.userAgentData && navigator.userAgentData.mobile) || navigator.userAgent.indexOf("Mobile") !== -1){
# 			return true;
# 		}
# 		else {
# 			return false;
# 		}
# 	}
#
# 	if ('serviceWorker' in navigator && !isMobile()) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && isMobile()){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }</script> <script async="" defer="defer" id="omni_script" nonce="16846393364431464201" src="///www/linchpin/batman-returns/omni/omni16.js"></script> <script nonce="16846393364431464201">window._pxAppId = 'PXgNtTli3A';</script><script async="" nonce="16846393364431464201" src="///px/gNtTli3A/init.js"></script></body></html>

# %%
# finds all <div> elements with the class _2kHMtA within the parsed HTML content and assigns them to the variable data
data = content.find_all('div', {'class': '_2kHMtA'})
data
# Out:
# [<div class="_2kHMtA"><a class="_1fQZEK" href="/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&amp;lid=LSTMOBG3VSKHGETEBVM0TO8SZ&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKHGETEBVM.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 11 Lite (Vinyl Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 11 Lite (Vinyl Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG3VSKHGETEBVM0TO8SZ_MOBG3VSKHGETEBVM_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>13,196 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,427 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.64 cm (6.55 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 8MP + 5MP | 16MP Front Camera</li><li class="rgWa7D">4250 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 732G Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Handset and 6 Months Warranty for In the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹13,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->24,999</div><div class="_3Ay6Sb"><span>44% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-11-lite-jazz-blue-128-gb/p/itme2c379bf49448?pid=MOBG3VSKEVZ3JQVM&amp;lid=LSTMOBG3VSKEVZ3JQVM1QRQHB&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKEVZ3JQVM.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 11 Lite (Jazz Blue, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/i/w/m/11-lite-m2101k9ai-mi-original-imag496gkgqjrvvg.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 11 Lite (Jazz Blue, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG3VSKEVZ3JQVM1QRQHB_MOBG3VSKEVZ3JQVM_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>13,196 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,427 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.64 cm (6.55 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 8MP + 5MP | 16MP Front Camera</li><li class="rgWa7D">4250 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 732G Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Handset and 6 Months Warranty for In the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹13,949</div><div class="_3I9_wc _27UcVY">₹<!-- -->24,999</div><div class="_3Ay6Sb"><span>44% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKRKGZKJAR&amp;lid=LSTMOBG3VSKRKGZKJAR9UUSWD&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_3&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKRKGZKJAR.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 11 Lite (Vinyl Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 11 Lite (Vinyl Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG3VSKRKGZKJAR9UUSWD_MOBG3VSKRKGZKJAR_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>6,332 Ratings </span><span class="_13vcmD">&amp;</span><span> 636 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.64 cm (6.55 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 8MP + 5MP | 16MP Front Camera</li><li class="rgWa7D">4250 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 732G Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Handset and 6 Months Warranty for In the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹23,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->25,999</div><div class="_3Ay6Sb"><span>7% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/xiaomi-11i-5g-purple-mist-128-gb/p/itmb0fd5926fb0d5?pid=MOBG9QXPXZTUYDY8&amp;lid=LSTMOBG9QXPXZTUYDY81BBAEL&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_4&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG9QXPXZTUYDY8.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Xiaomi 11i 5G (Purple Mist, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/ky7lci80/mobile/e/j/x/-original-imagag2gatsxzcuv.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Xiaomi 11i 5G (Purple Mist, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG9QXPXZTUYDY81BBAEL_MOBG9QXPXZTUYDY8_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>22,641 Ratings </span><span class="_13vcmD">&amp;</span><span> 2,748 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM | Expandable Upto 1 TB</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ AMOLED Display</li><li class="rgWa7D">108MP Rear Camera | 16MP Front Camera</li><li class="rgWa7D">5160 mAh Li-Polymer Battery</li><li class="rgWa7D">Mediatek Dimensity 920 Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹22,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->31,999</div><div class="_3Ay6Sb"><span>28% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-10t-pro-cosmic-black-128-gb/p/itm5ff5455fec520?pid=MOBFWAFZASEEEES6&amp;lid=LSTMOBFWAFZASEEEES6ZPPMMT&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_5&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBFWAFZASEEEES6.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 10T Pro (Cosmic Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kg6vfrk0/mobile/e/s/6/mi-10t-pro-mzb07zdin-original-imafwhbrythgcddt.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 10T Pro (Cosmic Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBFWAFZASEEEES6ZPPMMT_MOBFWAFZASEEEES6_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>3,707 Ratings </span><span class="_13vcmD">&amp;</span><span> 554 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ Display</li><li class="rgWa7D">108MP + 13MP + 5MP | 20MP Front Camera</li><li class="rgWa7D">5000 mAh Li-ion Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 865 Processor</li><li class="rgWa7D">144Hz Intelligent AdaptiveSync Display</li><li class="rgWa7D">33W Dual Split Flash Charge</li><li class="rgWa7D">1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹22,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->47,999</div><div class="_3Ay6Sb"><span>52% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/xiaomi-11i-5g-stealth-black-128-gb/p/itmf5300d828d19f?pid=MOBG9QXPQ2F8KGQD&amp;lid=LSTMOBG9QXPQ2F8KGQDBEHA2F&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_6&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG9QXPQ2F8KGQD.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Xiaomi 11i 5G (Stealth Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/ky7lci80/mobile/4/n/d/-original-imagag2gdzpdfsdf.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Xiaomi 11i 5G (Stealth Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG9QXPQ2F8KGQDBEHA2F_MOBG9QXPQ2F8KGQD_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>22,641 Ratings </span><span class="_13vcmD">&amp;</span><span> 2,748 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM | Expandable Upto 1 TB</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ AMOLED Display</li><li class="rgWa7D">108MP Rear Camera | 16MP Front Camera</li><li class="rgWa7D">5160 mAh Li-Polymer Battery</li><li class="rgWa7D">Mediatek Dimensity 920 Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹22,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->31,999</div><div class="_3Ay6Sb"><span>28% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-11x-lunar-white-128-gb/p/itmabc334b32f605?pid=MOBG36HSY24GH7GD&amp;lid=LSTMOBG36HSY24GH7GDKM83PH&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_7&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG36HSY24GH7GD.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 11X (Lunar White, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kp78e4w0/mobile/b/2/u/11x-11x-mi-original-imag3hqsshfzpv4u.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 11X (Lunar White, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG36HSY24GH7GDKM83PH_MOBG36HSY24GH7GD_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>3,186 Ratings </span><span class="_13vcmD">&amp;</span><span> 300 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">6 GB RAM | 128 GB ROM</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ Display</li><li class="rgWa7D">48MP + 8MP + 5MP | 20MP Front Camera</li><li class="rgWa7D">4520 mAh Battery</li><li class="rgWa7D">Qualcomm Snapdragon 870 Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹21,933</div><div class="_3I9_wc _27UcVY">₹<!-- -->33,999</div><div class="_3Ay6Sb"><span>35% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-6a-black-16-gb/p/itmdf93c982df80f?pid=MOBF9H95RFHUNBQZ&amp;lid=LSTMOBF9H95RFHUNBQZID6OKJ&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_8&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBF9H95RFHUNBQZ.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 6A (Black, 16 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/jpodaq80/mobile/b/q/z/mi-redmi-6a-redmi-6a-original-imafbv6guujwbz4z.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 6A (Black, 16 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBF9H95RFHUNBQZID6OKJ_MOBF9H95RFHUNBQZ_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>57,731 Ratings </span><span class="_13vcmD">&amp;</span><span> 3,903 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">2 GB RAM | 16 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.84 cm (5.45 inch) Display</li><li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li><li class="rgWa7D">3000 mAh Battery</li><li class="rgWa7D">1 Year Manufacturer Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹5,799</div><div class="_3I9_wc _27UcVY">₹<!-- -->7,999</div><div class="_3Ay6Sb"><span>27% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/xiaomi-11i-5g-camo-green-128-gb/p/itm5e173fdb5d441?pid=MOBG9QXPP5QRZZ3P&amp;lid=LSTMOBG9QXPP5QRZZ3PRQPSHC&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_9&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG9QXPP5QRZZ3P.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Xiaomi 11i 5G (Camo Green, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/ky7lci80/mobile/i/w/n/-original-imagag2gugrdkbwu.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Xiaomi 11i 5G (Camo Green, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG9QXPP5QRZZ3PRQPSHC_MOBG9QXPP5QRZZ3P_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>38,849 Ratings </span><span class="_13vcmD">&amp;</span><span> 4,673 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">6 GB RAM | 128 GB ROM | Expandable Upto 1 TB</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ AMOLED Display</li><li class="rgWa7D">108MP Rear Camera | 16MP Front Camera</li><li class="rgWa7D">5160 mAh Li-Polymer Battery</li><li class="rgWa7D">Mediatek Dimensity 920 Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹24,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->29,999</div><div class="_3Ay6Sb"><span>16% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-9a-sea-blue-32-gb/p/itmeabd39a0cd669?pid=MOBFVDAYEWNQNKHH&amp;lid=LSTMOBFVDAYEWNQNKHH71ZACK&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_10&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBFVDAYEWNQNKHH.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 9A (Sea Blue, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kesv0y80/mobile/w/g/r/mi-redmi-9a-b08696xb4b-original-imafve7pjpemhwk5.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 9A (Sea Blue, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBFVDAYEWNQNKHH71ZACK_MOBFVDAYEWNQNKHH_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>15,285 Ratings </span><span class="_13vcmD">&amp;</span><span> 914 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li><li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li><li class="rgWa7D">5000 mAh Battery</li><li class="rgWa7D">MediaTek Helio G25 Processor</li><li class="rgWa7D">1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹7,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->9,499</div><div class="_3Ay6Sb"><span>15% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-note-4-dark-grey-32-gb/p/itmeqgfhpbdprkec?pid=MOBEQ98TGHHPQJGH&amp;lid=LSTMOBEQ98TGHHPQJGHUIKCEE&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_11&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBEQ98TGHHPQJGH.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi Note 4 (Dark Grey, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/mobile/9/8/z/mi-redmi-note-4-na-original-imaeqdxjuadhagfc.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi Note 4 (Dark Grey, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBEQ98TGHHPQJGHUIKCEE_MOBEQ98TGHHPQJGH_"><div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>6,41,700 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,09,830 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">3 GB RAM | 32 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.97 cm (5.5 inch) Full HD Display</li><li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li><li class="rgWa7D">4100 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 625 64-bit Octa Core 2GHz Processor</li><li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹7,790</div><div class="_3I9_wc _27UcVY">₹<!-- -->11,499</div><div class="_3Ay6Sb"><span>32% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/peace-mi2/p/itm324f3746f5c0c?pid=MOBGPD63YA5NFZ4H&amp;lid=LSTMOBGPD63YA5NFZ4HBPAYNA&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_12&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBGPD63YA5NFZ4H.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Peace Mi2" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/m/t/h/mi2-mi2-peace-original-imagpd63qyb3qbeh.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Peace Mi2</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGPD63YA5NFZ4HBPAYNA_MOBGPD63YA5NFZ4H_"><div class="_3LWZlK">3.4<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>16 Ratings </span><span class="_13vcmD">&amp;</span><span> 2 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">64 MB RAM | 128 MB ROM</li><li class="rgWa7D">5.08 cm (2 inch) Display</li><li class="rgWa7D">0.3MP Rear Camera</li><li class="rgWa7D">2500 mAh Battery</li><li class="rgWa7D">1 Months Brand Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹1,199</div><div class="_3I9_wc _27UcVY">₹<!-- -->1,699</div><div class="_3Ay6Sb"><span>29% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/peace-mi4/p/itm169fc0b49ad80?pid=MOBGJVQAZDZHP7BF&amp;lid=LSTMOBGJVQAZDZHP7BFQOODZL&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_13&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBGJVQAZDZHP7BF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Peace Mi4" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/o/a/l/mi4-mi4-peace-original-imagjvqadcvfehrk.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Peace Mi4</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGJVQAZDZHP7BFQOODZL_MOBGJVQAZDZHP7BF_"><div class="_3LWZlK">3.1<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>36 Ratings </span><span class="_13vcmD">&amp;</span><span> 4 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">64 MB RAM | 128 MB ROM</li><li class="rgWa7D">4.57 cm (1.8 inch) Display</li><li class="rgWa7D">2500 mAh Battery</li><li class="rgWa7D">1 Months Brand Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹1,149</div><div class="_3I9_wc _27UcVY">₹<!-- -->1,499</div><div class="_3Ay6Sb"><span>23% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-6a-rose-gold-32-gb/p/itm1ed294a755383?pid=MOBFAMZB7HFYJUFX&amp;lid=LSTMOBFAMZB7HFYJUFXV95BY5&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_14&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBFAMZB7HFYJUFX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 6A (Rose Gold, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/k0lbdzk0pkrrdj/mobile/r/r/x/mi-redmi-6a-redmi-6a-m1804c3ci-original-imafem28tzjf7npj.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 6A (Rose Gold, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBFAMZB7HFYJUFXV95BY5_MOBFAMZB7HFYJUFX_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>57,731 Ratings </span><span class="_13vcmD">&amp;</span><span> 3,903 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">2 GB RAM | 32 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.84 cm (5.45 inch) HD Display</li><li class="rgWa7D">13MP Rear Camera</li><li class="rgWa7D">3000 mAh Battery</li><li class="rgWa7D">Mediateck Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹6,899</div><div class="_3I9_wc _27UcVY">₹<!-- -->6,999</div><div class="_3Ay6Sb"><span>1% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-note-4-gold-32-gb/p/itmeqgs9gwrfwpf2?pid=MOBEQ98T82CYVHGZ&amp;lid=LSTMOBEQ98T82CYVHGZJFZSK1&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_15&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBEQ98T82CYVHGZ.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi Note 4 (Gold, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/k1pbpu80pkrrdj/mobile/8/4/e/mi-redmi-note-4-mzb5540in-mzb5298in-original-imaf6mhr3bdmzmhb.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="u05wbu">Coming Soon</span></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi Note 4 (Gold, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBEQ98T82CYVHGZJFZSK1_MOBEQ98T82CYVHGZ_"><div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>6,41,700 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,09,830 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">3 GB RAM | 32 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.97 cm (5.5 inch) Full HD Display</li><li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li><li class="rgWa7D">4100 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 625 64-bit Octa Core 2GHz Processor</li><li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹10,999</div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-6a-gold-16-gb/p/itmdf93c982df80f?pid=MOBF9HGZGZBBA8RX&amp;lid=LSTMOBF9HGZGZBBA8RXTQWNUU&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_16&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBF9HGZGZBBA8RX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 6A (Gold, 16 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/jyxaw7k0/mobile/t/r/k/mi-redmi-6a-m1804c3ci-original-imafbhfyjgzjfybm.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 6A (Gold, 16 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBF9HGZGZBBA8RXTQWNUU_MOBF9HGZGZBBA8RX_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>57,731 Ratings </span><span class="_13vcmD">&amp;</span><span> 3,903 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">2 GB RAM | 16 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.84 cm (5.45 inch) Display</li><li class="rgWa7D">13MP Rear Camera</li><li class="rgWa7D">3000 mAh Battery</li><li class="rgWa7D">1 Year</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹6,499</div><div class="_3I9_wc _27UcVY">₹<!-- -->7,999</div><div class="_3Ay6Sb"><span>18% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-10t-cosmic-black-128-gb/p/itmcd714276806ef?pid=MOBFWAFZNCMVPHMZ&amp;lid=LSTMOBFWAFZNCMVPHMZCIEQUR&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_17&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBFWAFZNCMVPHMZ.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 10T (Cosmic Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kg6vfrk0/mobile/h/m/z/mi-10t-mzb07zain-original-imafwhbyyvhd3g9v.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 10T (Cosmic Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBFWAFZNCMVPHMZCIEQUR_MOBFWAFZNCMVPHMZ_"><div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>3,810 Ratings </span><span class="_13vcmD">&amp;</span><span> 480 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 13MP + 5MP | 20MP Front Camera</li><li class="rgWa7D">5000 mAh Li-ion Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 865 Processor</li><li class="rgWa7D">144Hz Intelligent AdaptiveSync Display</li><li class="rgWa7D">33W Dual Split Flash Charge</li><li class="rgWa7D">1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹23,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->37,999</div><div class="_3Ay6Sb"><span>36% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
# ...
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-9a-nature-green-32-gb/p/itmeabd39a0cd669?pid=MOBFVDA5QCGNZKH9&amp;lid=LSTMOBFVDA5QCGNZKH9LMSS7T&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_19&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBFVDA5QCGNZKH9.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 9A (Nature Green, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kesv0y80/mobile/k/h/9/mi-redmi-9a-b08696xb4b-original-imafve7pte7e4zmp.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 9A (Nature Green, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBFVDA5QCGNZKH9LMSS7T_MOBFVDA5QCGNZKH9_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>22,145 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,297 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">2 GB RAM | 32 GB ROM</li><li class="rgWa7D">16.59 cm (6.53 inch) Full HD+ Display</li><li class="rgWa7D">13MP Rear Camera</li><li class="rgWa7D">5000 mAh Battery</li><li class="rgWa7D">1 Year  Manufacturer Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹8,063</div><div class="_3I9_wc _27UcVY">₹<!-- -->8,999</div><div class="_3Ay6Sb"><span>10% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/xiaomi-14-jade-green-512-gb/p/itm617acb7cd715d?pid=MOBGYGCMYEJTGEPF&amp;lid=LSTMOBGYGCMYEJTGEPFUFDBXT&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_20&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBGYGCMYEJTGEPF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Xiaomi 14 (Jade Green, 512 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/b/i/o/14-mzb0gfcin-xiaomi-original-imagyrget5qy3gqw.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Xiaomi 14 (Jade Green, 512 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGYGCMYEJTGEPFUFDBXT_MOBGYGCMYEJTGEPF_"><div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>77 Ratings </span><span class="_13vcmD">&amp;</span><span> 17 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">12 GB RAM | 512 GB ROM</li><li class="rgWa7D">16.15 cm (6.36 inch) Display</li><li class="rgWa7D">50MP + 50MP + 50MP | 32MP Front Camera</li><li class="rgWa7D">4610 mAh Battery</li><li class="rgWa7D">Snapdragon 8 Gen 3 Mobile Platform Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹69,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->79,999</div><div class="_3Ay6Sb"><span>12% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-9a-nature-green-32-gb/p/itmeabd39a0cd669?pid=MOBFVDAFCKBNXQ7E&amp;lid=LSTMOBFVDAFCKBNXQ7ECXMBYZ&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_21&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBFVDAFCKBNXQ7E.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 9A (Nature Green, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kesv0y80/mobile/k/h/9/mi-redmi-9a-b08696xb4b-original-imafve7pte7e4zmp.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 9A (Nature Green, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBFVDAFCKBNXQ7ECXMBYZ_MOBFVDAFCKBNXQ7E_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>15,285 Ratings </span><span class="_13vcmD">&amp;</span><span> 914 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li><li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li><li class="rgWa7D">5000 mAh Battery</li><li class="rgWa7D">MediaTek Helio G25 Processor</li><li class="rgWa7D">1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹8,199</div><div class="_3I9_wc _27UcVY">₹<!-- -->9,499</div><div class="_3Ay6Sb"><span>13% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-6a-blue-16-gb/p/itm1ed294a755383?pid=MOBF9Z2Z3YDBSF6V&amp;lid=LSTMOBF9Z2Z3YDBSF6VYNX7QH&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_22&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBF9Z2Z3YDBSF6V.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 6A (Blue, 16 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/jmux18w0/mobile/f/6/v/mi-redmi-6a-redmi-6a-original-imaf9z2jhwzyfamv.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Redmi 6A (Blue, 16 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBF9Z2Z3YDBSF6VYNX7QH_MOBF9Z2Z3YDBSF6V_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>57,731 Ratings </span><span class="_13vcmD">&amp;</span><span> 3,903 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">2 GB RAM | 16 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.84 cm (5.45 inch) Display</li><li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li><li class="rgWa7D">3000 mAh Battery</li><li class="rgWa7D">1 Year Manufacturer Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹6,499</div><div class="_3I9_wc _27UcVY">₹<!-- -->7,999</div><div class="_3Ay6Sb"><span>18% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-11-lite-jazz-blue-128-gb/p/itmac6203bae9394?pid=MOBG3VSKQMCRP5CR&amp;lid=LSTMOBG3VSKQMCRP5CRTN8UYY&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_23&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKQMCRP5CR.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 11 Lite (Jazz Blue, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/i/w/m/11-lite-m2101k9ai-mi-original-imag496gkgqjrvvg.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 11 Lite (Jazz Blue, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG3VSKQMCRP5CRTN8UYY_MOBG3VSKQMCRP5CR_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>6,332 Ratings </span><span class="_13vcmD">&amp;</span><span> 636 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.64 cm (6.55 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 8MP + 5MP | 16MP Front Camera</li><li class="rgWa7D">4250 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 732G Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Handset and 6 Months Warranty for In the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹16,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->26,999</div><div class="_3Ay6Sb"><span>37% off</span></div></div></div></div></div></a></div>,
#  <div class="_2kHMtA"><a class="_1fQZEK" href="/xiaomi-11lite-ne-vinyl-black-128-gb/p/itme31941c31379f?pid=MOBG7F6CXRFJ8CF8&amp;lid=LSTMOBG7F6CXRFJ8CF8SUKJAH&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_24&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG7F6CXRFJ8CF8.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Xiaomi 11Lite NE (Vinyl Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/e/u/4/-original-imag7f6chqmz5hzd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Xiaomi 11Lite NE (Vinyl Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG7F6CXRFJ8CF8SUKJAH_MOBG7F6CXRFJ8CF8_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>2,131 Ratings </span><span class="_13vcmD">&amp;</span><span> 223 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM | Expandable Upto 1 TB</li><li class="rgWa7D">16.64 cm (6.55 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 8MP + 5MP | 20MP Front Camera</li><li class="rgWa7D">4250 mAh Battery</li><li class="rgWa7D">Qualcomm Snapdragon 778G Processor</li><li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹27,000</div><div class="_3I9_wc _27UcVY">₹<!-- -->33,999</div><div class="_3Ay6Sb"><span>20% off</span></div></div></div></div></div></a></div>]

# %%
# finds all <div> elements with the class _2kHMtA within the parsed HTML content and assigns them to the variable dat
data = content.find_all('div', {'class': '_2kHMtA'})
data[0]
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&amp;lid=LSTMOBG3VSKHGETEBVM0TO8SZ&amp;marketplace=FLIPKART&amp;q=mi+brand+phone&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKHGETEBVM.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=9za61uo1hs0000001711295490538&amp;qH=4aa7f10791b88761" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Mi 11 Lite (Vinyl Black, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Mi 11 Lite (Vinyl Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBG3VSKHGETEBVM0TO8SZ_MOBG3VSKHGETEBVM_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>13,196 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,427 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li><li class="rgWa7D">16.64 cm (6.55 inch) Full HD+ Display</li><li class="rgWa7D">64MP + 8MP + 5MP | 16MP Front Camera</li><li class="rgWa7D">4250 mAh Li-Polymer Battery</li><li class="rgWa7D">Qualcomm Snapdragon 732G Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Handset and 6 Months Warranty for In the Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹13,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->24,999</div><div class="_3Ay6Sb"><span>44% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>

# %%
# Initialize empty lists to store links and phone names
links = []
phone_name = []

# Base URL for constructing complete links
start_link = "https://www.flipkart.com"

# Iterate through each item in the 'data' list
for items in data:
    #  Extract the relative link for each item
    rest_link = items.find('a')['href']
    
    #     # Find the name of the phone
    name = items.find('div', attrs = {'class': '_4rR01T'})
    
    # Append the text of the 'name' element to the 'phone_name' list
    phone_name.append(name.text)
    
    # Construct the complete URL by combining the base URL and the relative link, then append it to the 'links' list
    links.append(start_link + rest_link)

# %%
print(phone_name[0])  # Print the first phone name
print(links[0]) # Print the corresponding link
# Out:
# Mi 11 Lite (Vinyl Black, 128 GB)
# https://www.flipkart.com/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&lid=LSTMOBG3VSKHGETEBVM0TO8SZ&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKHGETEBVM.SEARCH&ppt=None&ppn=None&ssid=9za61uo1hs0000001711295490538&qH=4aa7f10791b88761

# %%
# Create a dictionary containing the phone names and links
dataframe = {"Phone_names": phone_name, 
             "Links": links}

# Create a DataFrame from the dictionary
final_dataframe = pd.DataFrame(dataframe)

# Print the DataFrame
print(final_dataframe)
# Out:
#                                Phone_names  \
# 0         Mi 11 Lite (Vinyl Black, 128 GB)
# 1           Mi 11 Lite (Jazz Blue, 128 GB)
# 2         Mi 11 Lite (Vinyl Black, 128 GB)
# 3      Xiaomi 11i 5G (Purple Mist, 128 GB)
# 4        Mi 10T Pro (Cosmic Black, 128 GB)
# 5    Xiaomi 11i 5G (Stealth Black, 128 GB)
# 6             Mi 11X (Lunar White, 128 GB)
# 7                  Redmi 6A (Black, 16 GB)
# 8       Xiaomi 11i 5G (Camo Green, 128 GB)
# 9               Redmi 9A (Sea Blue, 32 GB)
# 10         Redmi Note 4 (Dark Grey, 32 GB)
# 11                               Peace Mi2
# 12                               Peace Mi4
# 13             Redmi 6A (Rose Gold, 32 GB)
# 14              Redmi Note 4 (Gold, 32 GB)
# 15                  Redmi 6A (Gold, 16 GB)
# 16           Mi 10T (Cosmic Black, 128 GB)
# 17        Redmi 9A (Midnight Black, 32 GB)
# 18          Redmi 9A (Nature Green, 32 GB)
# 19          Xiaomi 14 (Jade Green, 512 GB)
# 20          Redmi 9A (Nature Green, 32 GB)
# 21                  Redmi 6A (Blue, 16 GB)
# 22          Mi 11 Lite (Jazz Blue, 128 GB)
# 23  Xiaomi 11Lite NE (Vinyl Black, 128 GB)
#
#                                                 Links
# 0   https://www.flipkart.com/mi-11-lite-vinyl-blac...
# 1   https://www.flipkart.com/mi-11-lite-jazz-blue-...
# 2   https://www.flipkart.com/mi-11-lite-vinyl-blac...
# 3   https://www.flipkart.com/xiaomi-11i-5g-purple-...
# 4   https://www.flipkart.com/mi-10t-pro-cosmic-bla...
# 5   https://www.flipkart.com/xiaomi-11i-5g-stealth...
# 6   https://www.flipkart.com/mi-11x-lunar-white-12...
# 7   https://www.flipkart.com/redmi-6a-black-16-gb/...
# 8   https://www.flipkart.com/xiaomi-11i-5g-camo-gr...
# 9   https://www.flipkart.com/redmi-9a-sea-blue-32-...
# 10  https://www.flipkart.com/redmi-note-4-dark-gre...
# 11  https://www.flipkart.com/peace-mi2/p/itm324f37...
# 12  https://www.flipkart.com/peace-mi4/p/itm169fc0...
# 13  https://www.flipkart.com/redmi-6a-rose-gold-32...
# 14  https://www.flipkart.com/redmi-note-4-gold-32-...
# 15  https://www.flipkart.com/redmi-6a-gold-16-gb/p...
# 16  https://www.flipkart.com/mi-10t-cosmic-black-1...
# 17  https://www.flipkart.com/redmi-9a-midnight-bla...
# 18  https://www.flipkart.com/redmi-9a-nature-green...
# 19  https://www.flipkart.com/xiaomi-14-jade-green-...
# 20  https://www.flipkart.com/redmi-9a-nature-green...
# 21  https://www.flipkart.com/redmi-6a-blue-16-gb/p...
# 22  https://www.flipkart.com/mi-11-lite-jazz-blue-...
# 23  https://www.flipkart.com/xiaomi-11lite-ne-viny...

# %%
# Save the DataFrame 'final_dataframe' to a CSV file named "data.csv"
final_dataframe.to_csv("dataset\data.csv")

# %% [markdown]
# ### Get Product Image URL

# %%
# Initialize empty lists to store links, phone names, and image URLs
links = []
phone_name = []
image_urls = []

# Base URL for constructing complete links
start_link = "https://www.flipkart.com"

# Iterate through each item in the 'data' list
for items in data:
    # Extract the relative link for each item
    rest_link = items.find('a')['href']
    
    # Find the name of the phone
    name = items.find('div', attrs = {'class': '_4rR01T'})
    
    # Append the extracted name to the 'phone_name' list
    phone_name.append(name.text)
    
    # Append the complete URL to the 'links' list
    links.append(start_link + rest_link)
    
    # Find the image tag for each item
    image_tag = items.find('img', class_='_396cs4')
    
    # Check if image tag exists
    if image_tag:
        
        # Extract the source URL of the image
        image_url = image_tag['src']
        
        # Append the image URL to the 'image_urls' list
        image_urls.append(image_url)
    else:
        # If image tag doesn't exist, append None to indicate no image
        image_urls.append(None)

# %%
print(phone_name[0]) # Print the first phone name
print(links[0]) # Print the corresponding link
print(image_urls[2]) # Print the image URL for the third item
# Out:
# Mi 11 Lite (Vinyl Black, 128 GB)
# https://www.flipkart.com/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&lid=LSTMOBG3VSKHGETEBVM0TO8SZ&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKHGETEBVM.SEARCH&ppt=None&ppn=None&ssid=9za61uo1hs0000001711295490538&qH=4aa7f10791b88761
# https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70

# %%
# Create a dictionary containing the phone names and links
dataframe = {"Phone_names": phone_name, 
             "Links": links, 
             "Imaages": image_urls}

# Create a DataFrame from the dictionary
final_dataframe = pd.DataFrame(dataframe)

# Print the DataFrame
print(final_dataframe)
# Out:
#                                Phone_names  \
# 0         Mi 11 Lite (Vinyl Black, 128 GB)
# 1           Mi 11 Lite (Jazz Blue, 128 GB)
# 2         Mi 11 Lite (Vinyl Black, 128 GB)
# 3      Xiaomi 11i 5G (Purple Mist, 128 GB)
# 4        Mi 10T Pro (Cosmic Black, 128 GB)
# 5    Xiaomi 11i 5G (Stealth Black, 128 GB)
# 6             Mi 11X (Lunar White, 128 GB)
# 7                  Redmi 6A (Black, 16 GB)
# 8       Xiaomi 11i 5G (Camo Green, 128 GB)
# 9               Redmi 9A (Sea Blue, 32 GB)
# 10         Redmi Note 4 (Dark Grey, 32 GB)
# 11                               Peace Mi2
# 12                               Peace Mi4
# 13             Redmi 6A (Rose Gold, 32 GB)
# 14              Redmi Note 4 (Gold, 32 GB)
# 15                  Redmi 6A (Gold, 16 GB)
# 16           Mi 10T (Cosmic Black, 128 GB)
# 17        Redmi 9A (Midnight Black, 32 GB)
# 18          Redmi 9A (Nature Green, 32 GB)
# 19          Xiaomi 14 (Jade Green, 512 GB)
# 20          Redmi 9A (Nature Green, 32 GB)
# 21                  Redmi 6A (Blue, 16 GB)
# 22          Mi 11 Lite (Jazz Blue, 128 GB)
# 23  Xiaomi 11Lite NE (Vinyl Black, 128 GB)
#
#                                                 Links  \
# 0   https://www.flipkart.com/mi-11-lite-vinyl-blac...
# 1   https://www.flipkart.com/mi-11-lite-jazz-blue-...
# 2   https://www.flipkart.com/mi-11-lite-vinyl-blac...
# 3   https://www.flipkart.com/xiaomi-11i-5g-purple-...
# 4   https://www.flipkart.com/mi-10t-pro-cosmic-bla...
# 5   https://www.flipkart.com/xiaomi-11i-5g-stealth...
# 6   https://www.flipkart.com/mi-11x-lunar-white-12...
# 7   https://www.flipkart.com/redmi-6a-black-16-gb/...
# 8   https://www.flipkart.com/xiaomi-11i-5g-camo-gr...
# 9   https://www.flipkart.com/redmi-9a-sea-blue-32-...
# 10  https://www.flipkart.com/redmi-note-4-dark-gre...
# 11  https://www.flipkart.com/peace-mi2/p/itm324f37...
# 12  https://www.flipkart.com/peace-mi4/p/itm169fc0...
# 13  https://www.flipkart.com/redmi-6a-rose-gold-32...
# 14  https://www.flipkart.com/redmi-note-4-gold-32-...
# 15  https://www.flipkart.com/redmi-6a-gold-16-gb/p...
# 16  https://www.flipkart.com/mi-10t-cosmic-black-1...
# 17  https://www.flipkart.com/redmi-9a-midnight-bla...
# 18  https://www.flipkart.com/redmi-9a-nature-green...
# 19  https://www.flipkart.com/xiaomi-14-jade-green-...
# 20  https://www.flipkart.com/redmi-9a-nature-green...
# 21  https://www.flipkart.com/redmi-6a-blue-16-gb/p...
# 22  https://www.flipkart.com/mi-11-lite-jazz-blue-...
# 23  https://www.flipkart.com/xiaomi-11lite-ne-viny...
#
#                                               Imaages
# 0   https://rukminim2.flixcart.com/image/312/312/k...
# 1   https://rukminim2.flixcart.com/image/312/312/k...
# 2   https://rukminim2.flixcart.com/image/312/312/k...
# 3   https://rukminim2.flixcart.com/image/312/312/k...
# 4   https://rukminim2.flixcart.com/image/312/312/k...
# 5   https://rukminim2.flixcart.com/image/312/312/k...
# 6   https://rukminim2.flixcart.com/image/312/312/k...
# 7   https://rukminim2.flixcart.com/image/312/312/j...
# 8   https://rukminim2.flixcart.com/image/312/312/k...
# 9   https://rukminim2.flixcart.com/image/312/312/k...
# 10  https://rukminim2.flixcart.com/image/312/312/m...
# 11  https://rukminim2.flixcart.com/image/312/312/x...
# 12  https://rukminim2.flixcart.com/image/312/312/x...
# 13  https://rukminim2.flixcart.com/image/312/312/k...
# 14  https://rukminim2.flixcart.com/image/312/312/k...
# 15  https://rukminim2.flixcart.com/image/312/312/j...
# 16  https://rukminim2.flixcart.com/image/312/312/k...
# 17  https://rukminim2.flixcart.com/image/312/312/k...
# 18  https://rukminim2.flixcart.com/image/312/312/k...
# 19  https://rukminim2.flixcart.com/image/312/312/x...
# 20  https://rukminim2.flixcart.com/image/312/312/k...
# 21  https://rukminim2.flixcart.com/image/312/312/j...
# 22  https://rukminim2.flixcart.com/image/312/312/k...
# 23  https://rukminim2.flixcart.com/image/312/312/x...

# %%
# Save the DataFrame 'final_dataframe' to a CSV file named "data_image.csv"
final_dataframe.to_csv("dataset\data_image.csv")

# %% [markdown]
# ### Get Product Discount Price

# %%
# Initialize empty lists to store links, phone names, image URLs, selling prices
links = []
phone_name = []
image_urls = []
prices = []

# Base URL for constructing complete links
start_link = "https://www.flipkart.com"

# Iterate through each item in the 'data' list
for items in data:
    # Extract the relative link for each item
    rest_link = items.find('a')['href']
    
    # Find the name of the phone
    name = items.find('div', attrs = {'class': '_4rR01T'})
    
    # Append the extracted name to the 'phone_name' list
    phone_name.append(name.text)
    
    # Combine the base URL and the relative link to form the complete URL
    links.append(start_link + rest_link)
    
    # Find the image tag for each item
    image_tag = items.find('img', class_='_396cs4')
    
    # Check if image tag exists
    if image_tag:
        # Extract the source URL of the image
        image_url = image_tag['src']
        
        # Append the image URL to the 'image_urls' list
        image_urls.append(image_url)
    else:
        # If image tag doesn't exist, append None to indicate no image
        image_urls.append(None)
        
    # Extracting price
    price_tag = items.find('div', class_='_30jeq3 _1_WHN1')
    if price_tag:
        # Extract the price text and strip any leading/trailing whitespaces
        price = price_tag.text.strip()
        
        # Append the price to the 'prices' list
        prices.append(price)
    else:
        # If price tag doesn't exist, append None or any placeholder value
        prices.append(None)

# %%
print(phone_name[0])     # Print the phone name of the first item
print(links[0])          # Print the corresponding link of the first item
print(image_urls[0])     # Print the image URL of the first item
print(prices[0])         # Print the price of the first item
# Out:
# Mi 11 Lite (Vinyl Black, 128 GB)
# https://www.flipkart.com/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&lid=LSTMOBG3VSKHGETEBVM0TO8SZ&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKHGETEBVM.SEARCH&ppt=None&ppn=None&ssid=9za61uo1hs0000001711295490538&qH=4aa7f10791b88761
# https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70
# ₹13,990

# %%
print(image_urls[2])  # Print the image URL of the third item
# Out:
# https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70

# %%
# Create a dictionary containing phone names, links, image URLs, and prices
dataframe = {"Phone_names": phone_name, 
             "Links": links, 
             "Images": image_urls, 
             "Prices": prices}

# Create a DataFrame from the dictionary
final_dataframe = pd.DataFrame(dataframe)

# %%
final_dataframe.to_csv("dataset\data_price.csv")

# %% [markdown]
# ### Get Product Original Price

# %%
# Initialize empty lists to store links, phone names, image URLs, selling prices, and original prices
links = []
phone_name = []
image_urls = []
selling_prices = []
original_price = []

# Base URL for constructing complete links
start_link = "https://www.flipkart.com"

# Iterate through each item in the 'data' list
for items in data:
    # Extract the relative link for each item
    rest_link = items.find('a')['href']
    
    # Find the name of the phone
    name = items.find('div', attrs = {'class': '_4rR01T'})
    
    # Append the extracted name to the 'phone_name' list
    phone_name.append(name.text)
    
    # Combine the base URL and the relative link to form the complete URL
    links.append(start_link + rest_link)
    
    # Find the image tag for each item
    image_tag = items.find('img', class_='_396cs4')
    
    # Check if image tag exists
    if image_tag:
        
        # Extract the source URL of the image
        image_url = image_tag['src']
        
        # Append the image URL to the 'image_urls' list
        image_urls.append(image_url)
    else:
        # If image tag doesn't exist, append None to indicate no image
        image_urls.append(None)
        
    # Extracting selling price
    price_tag = items.find('div', class_='_30jeq3 _1_WHN1')
    if price_tag:
        price = price_tag.text.strip()
        selling_prices.append(price)
    else:
        selling_prices.append(None)
        
    # Extracting original price
    price_tag = items.find('div', class_='_3I9_wc _27UcVY')
    if price_tag:
        price = price_tag.text.strip()
        original_price.append(price)
    else:
        original_price.append(None)  # or any placeholder value if price is not found

# %%
print(phone_name[0]) # Print the first phone name
print(links[0]) # Print the corresponding link
print(image_urls[0]) # Print the image URL for the first item
print(selling_prices[0]) # Print the selling price for the first item
print(original_price[0]) # Print the original price for the first item
# Out:
# Mi 11 Lite (Vinyl Black, 128 GB)
# https://www.flipkart.com/mi-11-lite-vinyl-black-128-gb/p/itmac6203bae9394?pid=MOBG3VSKHGETEBVM&lid=LSTMOBG3VSKHGETEBVM0TO8SZ&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG3VSKHGETEBVM.SEARCH&ppt=None&ppn=None&ssid=9za61uo1hs0000001711295490538&qH=4aa7f10791b88761
# https://rukminim2.flixcart.com/image/312/312/kq6yefk0/mobile/b/2/f/11-lite-m2101k9ai-mi-original-imag496egxryygvz.jpeg?q=70
# ₹13,990
# ₹24,999

# %%
# Create a dictionary containing phone names, links, images, selling prices, and original prices
dataframe = {"Phone_names": phone_name, 
             "Links": links, 
             "Images": image_urls, 
             "Selling Prices": selling_prices, 
             "Original Prie": original_price}

# Create a DataFrame from the dictionary
final_dataframe = pd.DataFrame(dataframe)

# %%
# Save the DataFrame 'final_dataframe' to a CSV file named "data_price_sales.csv"
final_dataframe.to_csv("dataset\data_sales_original_price.csv")

# %% [markdown]
# ### Get Product Review

# %%
# Initialize empty lists to store links, phone names, image URLs, selling prices, original prices, and reviews
links = []
phone_name = []
image_urls = []
selling_prices = []
original_price = []
reviews = []

# Base URL for constructing complete links
start_link = "https://www.flipkart.com"

# Iterate through each item in the 'data' list
for items in data:
    # Extract the relative link for each item
    rest_link = items.find('a')['href']
    
    # Find the name of the phone
    name = items.find('div', attrs = {'class': '_4rR01T'})
    
    # Append the extracted name to the 'phone_name' list
    phone_name.append(name.text)
    
    # Combine the base URL and the relative link to form the complete URL
    links.append(start_link + rest_link)
    
    # Find the image tag for each item
    image_tag = items.find('img', class_='_396cs4')
    
    # Check if image tag exists
    if image_tag:
        # Extract the source URL of the image
        image_url = image_tag['src']
        # Append the image URL to the 'image_urls' list
        image_urls.append(image_url)
    else:
        # If image tag doesn't exist, append None to indicate no image
        image_urls.append(None)
        
    # Extracting selling price
    price_tag = items.find('div', class_='_30jeq3 _1_WHN1')
    if price_tag:
        price = price_tag.text.strip()
        selling_prices.append(price)
    else:
        selling_prices.append(None)
        
    # Extracting original price
    price_tag = items.find('div', class_='_3I9_wc _27UcVY')
    if price_tag:
        price = price_tag.text.strip()
        original_price.append(price)
    else:
        original_price.append(None)
        
    # Extracting reviews
    review_tag = items.find('span', class_='_1lRcqv')
    if review_tag:
        review = review_tag.text.strip()
        reviews.append(review)
    else:
        reviews.append(None)

# %%
print(phone_name[5])         # Print the phone name for the sixth item
print(links[5])              # Print the corresponding link for the sixth item
print(image_urls[5])         # Print the image URL for the sixth item
print(selling_prices[5])     # Print the selling price for the sixth item
print(original_price[5])     # Print the original price for the sixth item
print(reviews[5])            # Print the reviews for the sixth item
# Out:
# Xiaomi 11i 5G (Stealth Black, 128 GB)
# https://www.flipkart.com/xiaomi-11i-5g-stealth-black-128-gb/p/itmf5300d828d19f?pid=MOBG9QXPQ2F8KGQD&lid=LSTMOBG9QXPQ2F8KGQDBEHA2F&marketplace=FLIPKART&q=mi+brand+phone&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=bf3fb93f-d735-43d3-b741-cf21d6caa08a.MOBG9QXPQ2F8KGQD.SEARCH&ppt=None&ppn=None&ssid=9za61uo1hs0000001711295490538&qH=4aa7f10791b88761
# https://rukminim2.flixcart.com/image/312/312/ky7lci80/mobile/4/n/d/-original-imagag2gdzpdfsdf.jpeg?q=70
# ₹22,999
# ₹31,999
# 4.2

# %%
# Create a dictionary containing phone names, links, images, selling prices, original prices, and reviews
dataframe = {"Phone_names": phone_name, 
             "Links": links, 
             "Images": image_urls, 
             "Selling Prices": selling_prices, 
             "Original Prie": original_price,
             "Reviews": reviews}

# Create a DataFrame from the dictionary
final_dataframe = pd.DataFrame(dataframe)

# %%
# Save the DataFrame 'final_dataframe' to a CSV file named "reviews.csv"
final_dataframe.to_csv("reviews.csv")

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("reviews.csv")

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Unnamed: 0                          Phone_names  \
# 0           0     Mi 11 Lite (Vinyl Black, 128 GB)
# 1           1       Mi 11 Lite (Jazz Blue, 128 GB)
# 2           2     Mi 11 Lite (Vinyl Black, 128 GB)
# 3           3  Xiaomi 11i 5G (Purple Mist, 128 GB)
# 4           4    Mi 10T Pro (Cosmic Black, 128 GB)
#
#                                                Links  \
# 0  https://www.flipkart.com/mi-11-lite-vinyl-blac...
# 1  https://www.flipkart.com/mi-11-lite-jazz-blue-...
# 2  https://www.flipkart.com/mi-11-lite-vinyl-blac...
# 3  https://www.flipkart.com/xiaomi-11i-5g-purple-...
# 4  https://www.flipkart.com/mi-10t-pro-cosmic-bla...
#
#                                               Images Selling Prices  \
# 0  https://rukminim2.flixcart.com/image/312/312/k...        ₹13,990
# 1  https://rukminim2.flixcart.com/image/312/312/k...        ₹13,949
# 2  https://rukminim2.flixcart.com/image/312/312/k...        ₹23,999
# 3  https://rukminim2.flixcart.com/image/312/312/k...        ₹22,999
# 4  https://rukminim2.flixcart.com/image/312/312/k...        ₹22,999
#
#   Original Prie  Reviews
# 0       ₹24,999      4.2
# 1       ₹24,999      4.2
# 2       ₹25,999      4.2
# 3       ₹31,999      4.2
# 4       ₹47,999      4.2

# %%
# Save the DataFrame 'final_dataframe' to a CSV file named "final_data.csv"
final_dataframe.to_csv("final_data.csv")

# %% [markdown]
# # Multiple Pages Webscraping

# %%
import requests  # Importing the requests library for making HTTP requests
import pandas as pd  # Importing the pandas library for data manipulation
from bs4 import BeautifulSoup  # Importing BeautifulSoup for web scraping

# %%
page_number = input("Enter number of pages: ") # Prompt the user to input the number of pages

# Iterate through the range from 1 to the input number of pages
for i in range(1, int(page_number) + 1):
    
    # Construct the URL based on the current page number
    url = "https://www.flipkart.com/search?q=apple+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=apple+mobiles%7CMobiles&requestId=74513d15-9fcc-41ea-a7e0-16499e689ee3&as-backfill=on&otracker=nmenu_sub_Electronics_0_Apple&page="+str(i)
    
    # Send a GET request to the URL
    req = requests.get(url)
    
    # Parse the HTML content of the response
    content = BeautifulSoup(req.content, 'html.parser')
    #print(content)
# Out:
# Enter number of pages: 4

# %%
data = content.find_all('div', {'class': '_2kHMtA'}) # Extract all div elements with class '_2kHMtA'
data[0] # Access the first element in the 'data' list
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-15-plus-pink-512-gb/p/itme9cc36fe09419?pid=MOBGTAGP7JCP6YBB&amp;lid=LSTMOBGTAGP7JCP6YBB3TZGS0&amp;marketplace=FLIPKART&amp;q=apple+mobiles&amp;store=tyy%2F4io&amp;srno=s_4_73&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&amp;fm=organic&amp;iid=06d587e5-ee48-4b2c-b39d-571570e8b5c8.MOBGTAGP7JCP6YBB.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=42eqnylvq80000001711295584132&amp;qH=cb603b9543d774e1" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 15 Plus (Pink, 512 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/c/6/r/-original-imagtc6fn8fecysv.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Apple iPhone 15 Plus (Pink, 512 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGTAGP7JCP6YBB3TZGS0_MOBGTAGP7JCP6YBB_"><div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>3,907 Ratings </span><span class="_13vcmD">&amp;</span><span> 407 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">512 GB ROM</li><li class="rgWa7D">17.02 cm (6.7 inch) Super Retina XDR Display</li><li class="rgWa7D">48MP + 12MP | 12MP Front Camera</li><li class="rgWa7D">A16 Bionic Chip, 6 Core Processor Processor</li><li class="rgWa7D">1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹1,12,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->1,19,900</div><div class="_3Ay6Sb"><span>5% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/></div></div></div></a></div>

# %%
page_number = input("Enter number of pages: ") # Prompt the user to input the number of pages

# Iterate through the range from 1 to the input number of pages
for i in range(1, int(page_number) + 1):
    
    # Construct the URL based on the current page number
    url = "https://www.flipkart.com/search?q=apple+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=apple+mobiles%7CMobiles&requestId=74513d15-9fcc-41ea-a7e0-16499e689ee3&as-backfill=on&otracker=nmenu_sub_Electronics_0_Apple&page="+str(i)
    
    # Send a GET request to the URL
    req = requests.get(url)
    
    # Parse the HTML content of the response
    content = BeautifulSoup(req.content, 'html.parser')
    
    # Find all elements with class '_4rR01T' (phone names)
    name = content.find_all('div', {'class': '_4rR01T'})
    
    # Find all elements with class '_30jeq3 _1_WHN1' (selling prices)
    price = content.find_all('div', {'class': '_30jeq3 _1_WHN1'})
    
    # Print the number of phones in the current page
    print("Phone in page "+str(i))
    print(len(name))
# Out:
# Enter number of pages: 4
# Phone in page 1
# 24
# Phone in page 2
# 24
# Phone in page 3
# 24
# Phone in page 4
# 24

# %%
page_number = input("Enter number of pages: ")# Prompt the user to input the number of pages

# Iterate through the range from 1 to the input number of pages
for i in range(1, int(page_number) + 1):
    
    # Construct the URL based on the current page number
    url = "https://www.flipkart.com/search?q=apple+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=apple+mobiles%7CMobiles&requestId=74513d15-9fcc-41ea-a7e0-16499e689ee3&as-backfill=on&otracker=nmenu_sub_Electronics_0_Apple&page="+str(i)
    
    # Send a GET request to the URL
    req = requests.get(url)
    
    # Parse the HTML content of the response
    content = BeautifulSoup(req.content, 'html.parser')
    
    # Find all elements with class '_4rR01T' (phone names)
    name = content.find_all('div', {'class': '_4rR01T'})
    
    # Find all elements with class '_30jeq3 _1_WHN1' (selling prices)
    price = content.find_all('div', {'class': '_30jeq3 _1_WHN1'})
    
    # Print the label indicating the current page number
    print("Phone in page "+str(i))
    
    # Print the number of phones in the current page
    print(len(name))
# Out:
# Enter number of pages: 4
# Phone in page 1
# 24
# Phone in page 2
# 24
# Phone in page 3
# 24
# Phone in page 4
# 24

# %%
phone_name = [] # Initialize an empty list to store phone names
phone_price = [] # Initialize an empty list to store phone prices

# Prompt the user to input the number of pages
page_number = input("Enter number of pages: ")

# Iterate through the range from 1 to the input number of pages
for i in range(1, int(page_number) + 1):
    
    # Construct the URL based on the current page number
    url = "https://www.flipkart.com/search?q=apple+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=apple+mobiles%7CMobiles&requestId=74513d15-9fcc-41ea-a7e0-16499e689ee3&as-backfill=on&otracker=nmenu_sub_Electronics_0_Apple&page="+str(i)
    
    # Send a GET request to the URL
    req = requests.get(url)
    
    # Parse the HTML content of the response
    content = BeautifulSoup(req.content, 'html.parser')
    
    # Find all elements with class '_4rR01T' (phone names)
    name = content.find_all('div', {'class': '_4rR01T'})
    
    # Find all elements with class '_30jeq3 _1_WHN1' (selling prices)
    price = content.find_all('div', {'class': '_30jeq3 _1_WHN1'})
    
    # Print the label indicating the current page number
    print("Phone in page "+str(i))
    
    # Print the number of phones in the current page
    print(len(name))
    
    # Iterate through each phone name element and append its text to the 'phone_name' list
    for i in name:
        phone_name.append(i.text)

    # Iterate through each phone price element and append its text to the 'phone_price' list
    for i in price:
        phone_price.append(i.text)
# Out:
# Enter number of pages: 4
# Phone in page 1
# 24
# Phone in page 2
# 24
# Phone in page 3
# 24
# Phone in page 4
# 24

# %%
# Iterate through each item in the 'phone_price' list and print each item (representing the price of a phone)
for i in phone_price:
    print(i)
# Out:
# ₹67,999
# ₹67,999
# ₹56,999
# ₹56,999
# ₹67,999
# ₹56,999
# ₹56,999
# ₹52,999
# ₹52,999
# ₹68,999
# ₹52,999
# ₹66,999
# ₹52,999
# ₹52,999
# ₹56,999
# ₹66,999
# ₹66,999
# ₹82,999
# ₹66,999
# ₹82,999
# ₹96,999
# ₹80,999
# ₹82,999
# ₹80,999
# ₹68,999
# ₹1,27,990
# ₹1,58,990
# ₹66,999
# ₹80,999
# ₹82,999
# ₹1,27,990
# ₹96,999
# ₹1,37,990
# ₹76,999
# ₹1,58,990
# ₹80,999
# ₹92,999
# ₹82,999
# ₹1,37,990
# ₹86,999
# ₹44,999
# ₹69,999
# ₹57,999
# ₹44,999
# ₹44,999
# ₹43,900
# ₹76,999
# ₹69,999
# ₹96,999
# ₹1,48,900
# ₹92,999
# ₹43,900
# ₹92,999
# ₹1,12,999
# ₹1,37,990
# ₹44,999
# ₹43,900
# ₹1,48,900
# ₹48,900
# ₹1,77,990
# ₹1,48,900
# ₹50,999
# ₹1,27,990
# ₹1,77,990
# ₹86,999
# ₹69,999
# ₹80,999
# ₹69,999
# ₹92,999
# ₹1,58,990
# ₹1,77,990
# ₹1,12,999
# ₹76,999
# ₹1,77,990
# ₹96,999
# ₹97,999
# ₹86,999
# ₹59,900
# ₹97,999
# ₹59,900
# ₹97,999
# ₹60,999
# ₹43,900
# ₹1,79,900
# ₹48,900
# ₹1,79,900
# ₹1,12,999
# ₹1,48,900
# ₹64,900
# ₹43,900
# ₹48,900
# ₹48,999
# ₹1,12,999
# ₹48,900
# ₹1,37,990
# ₹60,999

# %%
# Iterate through each item in the 'phone_name' list and print each item
for i in phone_name:
    print(i)
# Out:
# Apple iPhone 15 (Blue, 128 GB)
# Apple iPhone 15 (Green, 128 GB)
# Apple iPhone 14 (Blue, 128 GB)
# Apple iPhone 14 (Starlight, 128 GB)
# Apple iPhone 15 (Black, 128 GB)
# Apple iPhone 14 (Purple, 128 GB)
# Apple iPhone 14 (Midnight, 128 GB)
# Apple iPhone 13 (Pink, 128 GB)
# Apple iPhone 13 (Starlight, 128 GB)
# Apple iPhone 15 (Pink, 128 GB)
# Apple iPhone 13 (Green, 128 GB)
# Apple iPhone 14 Plus (Midnight, 128 GB)
# Apple iPhone 13 (Midnight, 128 GB)
# Apple iPhone 13 (Blue, 128 GB)
# Apple iPhone 14 ((PRODUCT)RED, 128 GB)
# Apple iPhone 14 Plus (Starlight, 128 GB)
# Apple iPhone 14 Plus (Blue, 128 GB)
# Apple iPhone 15 Plus (Green, 128 GB)
# Apple iPhone 14 Plus (Purple, 128 GB)
# Apple iPhone 15 Plus (Yellow, 128 GB)
# Apple iPhone 14 Plus (Yellow, 512 GB)
# Apple iPhone 15 (Pink, 256 GB)
# Apple iPhone 15 Plus (Black, 128 GB)
# Apple iPhone 15 (Green, 256 GB)
# Apple iPhone 15 (Yellow, 128 GB)
# Apple iPhone 15 Pro (White Titanium, 128 GB)
# Apple iPhone 15 Pro (Black Titanium, 512 GB)
# Apple iPhone 14 Plus (Yellow, 128 GB)
# Apple iPhone 15 (Black, 256 GB)
# Apple iPhone 15 Plus (Blue, 128 GB)
# Apple iPhone 15 Pro (Black Titanium, 128 GB)
# Apple iPhone 14 Plus (Starlight, 512 GB)
# Apple iPhone 15 Pro (Black Titanium, 256 GB)
# Apple iPhone 14 Plus (Starlight, 256 GB)
# Apple iPhone 15 Pro (White Titanium, 512 GB)
# Apple iPhone 15 (Blue, 256 GB)
# Apple iPhone 15 Plus (Pink, 256 GB)
# Apple iPhone 15 Plus (Pink, 128 GB)
# Apple iPhone 15 Pro (White Titanium, 256 GB)
# Apple iPhone 14 (Yellow, 512 GB)
# Apple iPhone 12 (Blue, 64 GB)
# Apple iPhone 14 (Purple, 256 GB)
# Apple iPhone 14 (Yellow, 128 GB)
# Apple iPhone 12 (Black, 64 GB)
# Apple iPhone 12 (White, 64 GB)
# Apple iPhone 11 (Red, 64 GB)
# Apple iPhone 14 Plus ((PRODUCT)RED, 256 GB)
# Apple iPhone 14 (Midnight, 256 GB)
# Apple iPhone 14 Plus ((PRODUCT)RED, 512 GB)
# Apple iPhone 15 Pro Max (Natural Titanium, 256 GB)
# Apple iPhone 15 Plus (Black, 256 GB)
# Apple iPhone 11 (Purple, 64 GB)
# Apple iPhone 15 Plus (Blue, 256 GB)
# Apple iPhone 15 Plus (Black, 512 GB)
# Apple iPhone 15 Pro (Blue Titanium, 256 GB)
# Apple iPhone 12 (Red, 64 GB)
# Apple iPhone 11 (Green, 64 GB)
# Apple iPhone 15 Pro Max (Blue Titanium, 256 GB)
# Apple iPhone 11 (Purple, 128 GB)
# Apple iPhone 15 Pro (Natural Titanium, 1 TB)
# Apple iPhone 15 Pro Max (White Titanium, 256 GB)
# Apple iPhone 12 (Blue, 128 GB)
# Apple iPhone 15 Pro (Natural Titanium, 128 GB)
# Apple iPhone 15 Pro (Black Titanium, 1 TB)
# Apple iPhone 14 ((PRODUCT)RED, 512 GB)
# Apple iPhone 14 (Blue, 256 GB)
# Apple iPhone 15 (Yellow, 256 GB)
# Apple iPhone 14 (Starlight, 256 GB)
# Apple iPhone 15 Plus (Yellow, 256 GB)
# Apple iPhone 15 Pro (Natural Titanium, 512 GB)
# Apple iPhone 15 Pro (White Titanium, 1 TB)
# Apple iPhone 15 Plus (Pink, 512 GB)
# Apple iPhone 14 Plus (Yellow, 256 GB)
# Apple iPhone 15 Pro (Blue Titanium, 1 TB)
# Apple iPhone 14 Plus (Blue, 512 GB)
# Apple iPhone 15 (Black, 512 GB)
# Apple iPhone 14 (Midnight, 512 GB)
# Apple iPhone 12 mini (Blue, 64 GB)
# Apple iPhone 15 (Blue, 512 GB)
# Apple iPhone 12 mini (Black, 64 GB)
# Apple iPhone 15 (Green, 512 GB)
# Apple iPhone 12 (Black, 256 GB)
# Apple iPhone 11 (Black, 64 GB)
# Apple iPhone 13 Pro Max (Alpine Green, 1 TB)
# Apple iPhone 11 (White, 128 GB)
# Apple iPhone 13 Pro Max (Silver, 1 TB)
# Apple iPhone 15 Plus (Blue, 512 GB)
# Apple iPhone 15 Pro Max (Black Titanium, 256 GB)
# Apple iPhone 13 ((PRODUCT)RED, 256 GB)
# Apple iPhone 11 (White, 64 GB)
# Apple iPhone 11 (Black, 128 GB)
# Apple iPhone 6 Plus (Silver, 64 GB)
# Apple iPhone 15 Plus (Yellow, 512 GB)
# Apple iPhone 11 (Green, 128 GB)
# Apple iPhone 15 Pro (Natural Titanium, 256 GB)
# Apple iPhone 12 (Purple, 256 GB)

# %%
# Create a dictionary containing phone names and prices
data = {"Phone_name":phone_name,
       "Phone_Price": phone_price}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#                                         Phone_name Phone_Price
# 0                   Apple iPhone 15 (Blue, 128 GB)     ₹67,999
# 1                  Apple iPhone 15 (Green, 128 GB)     ₹67,999
# 2                   Apple iPhone 14 (Blue, 128 GB)     ₹56,999
# 3              Apple iPhone 14 (Starlight, 128 GB)     ₹56,999
# 4                  Apple iPhone 15 (Black, 128 GB)     ₹67,999
# ..                                             ...         ...
# 91             Apple iPhone 6 Plus (Silver, 64 GB)     ₹48,999
# 92           Apple iPhone 15 Plus (Yellow, 512 GB)   ₹1,12,999
# 93                 Apple iPhone 11 (Green, 128 GB)     ₹48,900
# 94  Apple iPhone 15 Pro (Natural Titanium, 256 GB)   ₹1,37,990
# 95                Apple iPhone 12 (Purple, 256 GB)     ₹60,999
#
# [96 rows x 2 columns]
